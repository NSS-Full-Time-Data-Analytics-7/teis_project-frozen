# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import re
from tqdm.notebook import tqdm

# %matplotlib inline

# %%
final_data = pd.read_csv('../data/teis_final_data.csv')
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115524 entries, 0 to 115523
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Child ID                   115524 non-null  int64
#  1   Notification Date          115524 non-null  object
#  2   Fiscal Year                113256 non-null  object
#  3   Notification Month         113256 non-null  object
#  4   Tenn Region                113256 non-null  object
#  5   Fiscal Year.1              113256 non-null  float64
#  6   third_DOB                  113256 non-null  object
#  7   Late Referral              2829 non-null    float64
#  8   Qtr                        113256 non-null  float64
#  9   POE                        115524 non-null  object
#  10  DOB                        115524 non-null  object
#  11  County Name                115520 non-null  object
#  12  County SES                 115520 non-null  object
#  13  Child Phase                115524 non-null  object
#  14  Active                     96580 non-null   object
#  15  Service Coordinator        115523 non-null  object
#  16  Parent Consent             75365 non-null   object
#  17  Initial Eligibility        71884 non-null   object
#  18  Initial Eligibility Date   71884 non-null   object
#  19  Initial IFSP Date          45520 non-null   object
#  20  Latest IFSP                44539 non-null   object
#  21  Exit Reason                96177 non-null   object
#  22  Exit Date                  85194 non-null   object
#  23  Referral Source Type Name  115524 non-null  object
#  24  Year                       115524 non-null  int64
# dtypes: float64(3), int64(2), object(20)
# memory usage: 22.0+ MB

# %%
monthly_df = pd.read_excel('../data/TEIS Compiled Monthly.xlsx')
monthly_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113256 entries, 0 to 113255
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   POE                          113256 non-null  object
#  1   Child ID                     113256 non-null  int64
#  2   DOB                          113256 non-null  datetime64[ns]
#  3   County Name                  113251 non-null  object
#  4   County SES                   113251 non-null  object
#  5   Child Phase                  113256 non-null  object
#  6   Active                       113256 non-null  object
#  7   Service Coordinator          113255 non-null  object
#  8   Notification/ Referral Date  113256 non-null  datetime64[ns]
#  9   Parent Consent Date          58101 non-null   datetime64[ns]
#  10  Referral Source Type Name    113256 non-null  object
#  11  Initial Eligibility          40762 non-null   object
#  12  Initial Eligibility Date     40762 non-null   object
#  13  Initial IFSP Date            8010 non-null    object
#  14  Latest IFSP Date             7983 non-null    object
#  15  Exit Reason                  39366 non-null   object
#  16  Exit Date                    39366 non-null   object
#  17  Fiscal Year                  113256 non-null  object
#  18  Notification Month           113256 non-null  object
#  19  Tenn Region                  113256 non-null  object
#  20  Referral Count               113256 non-null  int64
#  21  Evaluation Count             59469 non-null   float64
#  22  Eligibility Count            40762 non-null   float64
#  23  IFSP Count                   8010 non-null    float64
#  24  Service Coordinator Counter  113256 non-null  int64
#  25  Fiscal Year.1                113256 non-null  int64
#  26  Child Count                  113256 non-null  int64
#  27  2012 Child Count             0 non-null       float64
#  28  2013 Child Count             0 non-null       float64
#  29  third DOB                    113256 non-null  datetime64[ns]
#  30  Late Referral                2829 non-null    float64
#  31  Qtr                          113256 non-null  int64
#  32   QTR                         113256 non-null  object
#  33  Referral Source Category     0 non-null       float64
# dtypes: datetime64[ns](4), float64(7), int64(6), object(17)
# memory usage: 29.4+ MB

# %%
referral_df = pd.read_excel('../data/TEIS Referral Data.xlsx')

# %%
referral_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96580 entries, 0 to 96579
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   POE                        96580 non-null  object
#  1   Child ID                   96580 non-null  int64
#  2   DOB                        96580 non-null  datetime64[ns]
#  3   County Name                96576 non-null  object
#  4   County SES                 96576 non-null  object
#  5   Child Phase                96580 non-null  object
#  6   Active                     96580 non-null  object
#  7   Service Coordinator        96579 non-null  object
#  8   Notification Date          96580 non-null  datetime64[ns]
#  9   Parent Consent Date        70026 non-null  datetime64[ns]
#  10  Referral Source Type Name  96580 non-null  object
#  11  Initial Eligibility        68221 non-null  object
#  12  Initial Eligibility Date   68221 non-null  datetime64[ns]
#  13  Initial IFSP Date          45493 non-null  datetime64[ns]
#  14  Latest IFSP Date           44331 non-null  datetime64[ns]
#  15  Exit Reason                85194 non-null  object
#  16  Exit Date                  85194 non-null  datetime64[ns]
# dtypes: datetime64[ns](7), int64(1), object(9)
# memory usage: 12.5+ MB

# %% [markdown]
# ### Merge DataFrames

# %%
monthly_df = monthly_df.rename(columns = {'Notification/ Referral Date': 'Notification Date'})
referral_df = referral_df.rename(columns = {'County SES ': 'County SES'})

# %%
for ind, row in monthly_df.iterrows():
    if re.search('\d{5}', str(row['Exit Date'])):
        monthly_df.loc[ind, 'Exit Date'] = np.NaN
    if re.search('\d{5}', str(row['Latest IFSP Date'])):
        monthly_df.loc[ind, 'Latest IFSP Date'] = np.NaN
    if re.search('\d{5}', str(row['Initial IFSP Date'])):
        monthly_df.loc[ind, 'Initial IFSP Date'] = np.NaN
    if re.search('\d{5}', str(row['Initial Eligibility Date'])):
        monthly_df.loc[ind, 'Initial Eligibility Date'] = np.NaN

# %%
monthly_df["Exit Date"] = pd.to_datetime(monthly_df["Exit Date"])
monthly_df['Latest IFSP Date'] = pd.to_datetime(monthly_df['Latest IFSP Date'])
monthly_df['Initial IFSP Date'] = pd.to_datetime(monthly_df['Initial IFSP Date'])
monthly_df['Initial Eligibility Date'] = pd.to_datetime(monthly_df['Initial Eligibility Date'])

# %%
merge = pd.merge(monthly_df, referral_df, how = 'outer')
merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184750 entries, 0 to 184749
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   POE                          184750 non-null  object
#  1   Child ID                     184750 non-null  int64
#  2   DOB                          184750 non-null  datetime64[ns]
#  3   County Name                  184742 non-null  object
#  4   County SES                   184742 non-null  object
#  5   Child Phase                  184750 non-null  object
#  6   Active                       184750 non-null  object
#  7   Service Coordinator          184749 non-null  object
#  8   Notification Date            184750 non-null  datetime64[ns]
#  9   Parent Consent Date          120196 non-null  datetime64[ns]
#  10  Referral Source Type Name    184750 non-null  object
#  11  Initial Eligibility          101091 non-null  object
#  12  Initial Eligibility Date     100797 non-null  datetime64[ns]
#  13  Initial IFSP Date            53082 non-null   datetime64[ns]
#  14  Latest IFSP Date             51898 non-null   datetime64[ns]
#  15  Exit Reason                  99946 non-null   object
#  16  Exit Date                    99701 non-null   datetime64[ns]
#  17  Fiscal Year                  113256 non-null  object
#  18  Notification Month           113256 non-null  object
#  19  Tenn Region                  113256 non-null  object
#  20  Referral Count               113256 non-null  float64
#  21  Evaluation Count             59469 non-null   float64
#  22  Eligibility Count            40762 non-null   float64
#  23  IFSP Count                   8010 non-null    float64
#  24  Service Coordinator Counter  113256 non-null  float64
#  25  Fiscal Year.1                113256 non-null  float64
#  26  Child Count                  113256 non-null  float64
#  27  2012 Child Count             0 non-null       float64
#  28  2013 Child Count             0 non-null       float64
#  29  third DOB                    113256 non-null  datetime64[ns]
#  30  Late Referral                2829 non-null    float64
#  31  Qtr                          113256 non-null  float64
#  32   QTR                         113256 non-null  object
#  33  Referral Source Category     0 non-null       float64
# dtypes: datetime64[ns](8), float64(12), int64(1), object(13)
# memory usage: 49.3+ MB

# %%
full_teis = pd.concat([monthly_df, referral_df])

# %%
teis_clean = full_teis[~full_teis.duplicated(['POE', 'Child ID', 'DOB', 'County Name', 'County SES', 'Child Phase',
       'Active', 'Service Coordinator', 'Notification Date',
       'Parent Consent Date', 'Referral Source Type Name',
       'Initial Eligibility', 'Initial Eligibility Date', 'Initial IFSP Date',
       'Latest IFSP Date', 'Exit Reason', 'Exit Date'])]
teis_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184750 entries, 0 to 96579
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   POE                          184750 non-null  object
#  1   Child ID                     184750 non-null  int64
#  2   DOB                          184750 non-null  datetime64[ns]
#  3   County Name                  184742 non-null  object
#  4   County SES                   184742 non-null  object
#  5   Child Phase                  184750 non-null  object
#  6   Active                       184750 non-null  object
#  7   Service Coordinator          184749 non-null  object
#  8   Notification Date            184750 non-null  datetime64[ns]
#  9   Parent Consent Date          120196 non-null  datetime64[ns]
#  10  Referral Source Type Name    184750 non-null  object
#  11  Initial Eligibility          101091 non-null  object
#  12  Initial Eligibility Date     100797 non-null  datetime64[ns]
#  13  Initial IFSP Date            53082 non-null   datetime64[ns]
#  14  Latest IFSP Date             51898 non-null   datetime64[ns]
#  15  Exit Reason                  99946 non-null   object
#  16  Exit Date                    99701 non-null   datetime64[ns]
#  17  Fiscal Year                  113256 non-null  object
#  18  Notification Month           113256 non-null  object
#  19  Tenn Region                  113256 non-null  object
#  20  Referral Count               113256 non-null  float64
#  21  Evaluation Count             59469 non-null   float64
#  22  Eligibility Count            40762 non-null   float64
#  23  IFSP Count                   8010 non-null    float64
#  24  Service Coordinator Counter  113256 non-null  float64
#  25  Fiscal Year.1                113256 non-null  float64
#  26  Child Count                  113256 non-null  float64
#  27  2012 Child Count             0 non-null       float64
#  28  2013 Child Count             0 non-null       float64
#  29  third DOB                    113256 non-null  datetime64[ns]
#  30  Late Referral                2829 non-null    float64
#  31  Qtr                          113256 non-null  float64
#  32   QTR                         113256 non-null  object
#  33  Referral Source Category     0 non-null       float64
# dtypes: datetime64[ns](8), float64(12), int64(1), object(13)
# memory usage: 49.3+ MB

# %%
teis_clean[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']] = teis_clean[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']].apply(pd.to_datetime)
teis_clean
# Out:
# C:\Users\sethm\anaconda\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#       POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0      ET    403339 2014-08-09      Blount  Transitional   Eligibility      A
# 1      FT    404085 2013-07-31      Unicoi       At-Risk  Notification      I
# 2      FT    403623 2016-02-05    Sullivan  Transitional   Eligibility      A
# 3      FT    404157 2015-12-06    Sullivan  Transitional          IFSP      A
# 4      FT    404154 2015-04-18     Hawkins       At-Risk          IFSP      A
# ...    ..       ...        ...         ...           ...           ...    ...
# 96572  UC    523485 2019-10-23      Sumner   Competitive          IFSP      A
# 96573  UC    528430 2022-01-05  Cumberland  Transitional          IFSP      A
# 96574  UC    515685 2019-08-14      Sumner   Competitive          IFSP      A
# 96577  UC    525460 2019-08-27      Sumner   Competitive  Notification      I
# 96579  UC    514216 2021-02-04      Sumner   Competitive          IFSP      I
#
#                 Service Coordinator Notification Date Parent Consent Date  \
# 0                      Kristi Borer        2016-07-01          2016-07-01
# 1      Jennifer Terranera - 45 days        2016-07-01                 NaT
# 2                       Amy Talbert        2016-07-01          2016-07-20
# 3                    Candice Cradic        2016-07-01          2016-07-22
# 4                    Kathy Jeffries        2016-07-01          2016-07-18
# ...                             ...               ...                 ...
# 96572               Miriam Espinosa        2022-03-02          2022-03-10
# 96573                    Lisa Davis        2022-05-10          2022-05-18
# 96574                 Cindy Willard        2021-12-01          2021-12-07
# 96577             Sherry Roberts-DS        2022-03-29                 NaT
# 96579                     Dawn Reed        2021-11-05          2021-11-10
#
#        ... Service Coordinator Counter Fiscal Year.1 Child Count  \
# 0      ...                         1.0        2016.0         1.0
# 1      ...                         1.0        2016.0         1.0
# 2      ...                         1.0        2016.0         1.0
# 3      ...                         1.0        2016.0         1.0
# 4      ...                         1.0        2016.0         1.0
# ...    ...                         ...           ...         ...
# 96572  ...                         NaN           NaN         NaN
# 96573  ...                         NaN           NaN         NaN
# 96574  ...                         NaN           NaN         NaN
# 96577  ...                         NaN           NaN         NaN
# 96579  ...                         NaN           NaN         NaN
#
#       2012 Child Count 2013 Child Count  third DOB Late Referral  Qtr   QTR   \
# 0                  NaN              NaN 2017-08-09           NaN  1.0  Qtr 1
# 1                  NaN              NaN 2016-07-31           1.0  1.0  Qtr 1
# 2                  NaN              NaN 2019-02-05           NaN  1.0  Qtr 1
# 3                  NaN              NaN 2018-12-06           NaN  1.0  Qtr 1
# 4                  NaN              NaN 2018-04-18           NaN  1.0  Qtr 1
# ...                ...              ...        ...           ...  ...    ...
# 96572              NaN              NaN        NaT           NaN  NaN    NaN
# 96573              NaN              NaN        NaT           NaN  NaN    NaN
# 96574              NaN              NaN        NaT           NaN  NaN    NaN
# 96577              NaN              NaN        NaT           NaN  NaN    NaN
# 96579              NaN              NaN        NaT           NaN  NaN    NaN
#
#       Referral Source Category
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 96572                      NaN
# 96573                      NaN
# 96574                      NaN
# 96577                      NaN
# 96579                      NaN
#
# [184750 rows x 34 columns]

# %%
teis_clean = teis_clean.drop(columns = ['2012 Child Count', '2013 Child Count', 'Service Coordinator Counter', 'Referral Count',
                                        'Evaluation Count', 'Eligibility Count', 'IFSP Count', 'Child Count', ' QTR ', 
                                       'Referral Source Category'])
teis_clean.head(2)
# Out:
#   POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0  ET    403339 2014-08-09      Blount  Transitional   Eligibility      A
# 1  FT    404085 2013-07-31      Unicoi       At-Risk  Notification      I
#
#             Service Coordinator Notification Date Parent Consent Date  ...  \
# 0                  Kristi Borer        2016-07-01          2016-07-01  ...
# 1  Jennifer Terranera - 45 days        2016-07-01                 NaT  ...
#
#   Latest IFSP Date                 Exit Reason  Exit Date Fiscal Year  \
# 0              NaT                         NaN        NaT   2016-2017
# 1              NaT  Referral less than 45 days 2016-07-01   2016-2017
#
#   Notification Month Tenn Region Fiscal Year.1  third DOB Late Referral  Qtr
# 0                Jul     Eastern        2016.0 2017-08-09           NaN  1.0
# 1                Jul     Eastern        2016.0 2016-07-31           1.0  1.0
#
# [2 rows x 24 columns]

# %%
all_teis_dups = teis_clean[teis_clean.duplicated(['Child ID', 'Notification Date'], keep=False)].sort_values('Child ID')
all_teis_dups
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 8367    NW    351755 2013-11-13     Madison  Transitional   Eligibility
# 437     NW    351755 2013-11-13     Madison  Transitional    Evaluation
# 1552    UC    353805 2013-12-04      Putnam  Transitional    Evaluation
# 13240   UC    353805 2013-12-04      Putnam  Transitional          IFSP
# 4142    MD    353900 2013-10-09      Shelby  Transitional  Notification
# ...     ..       ...        ...         ...           ...           ...
# 113190  UC    529587 2022-03-15      Sumner   Competitive    Evaluation
# 93343   SE    529597 2020-04-10      McMinn  Transitional   Eligibility
# 112947  SE    529597 2020-04-10      McMinn  Transitional  Notification
# 111777  FT    529609 2020-05-13  Washington  Transitional  Notification
# 81090   FT    529609 2020-05-13  Washington  Transitional  Notification
#
#        Active    Service Coordinator Notification Date Parent Consent Date  \
# 8367        I              Rene Bard        2016-07-12          2016-07-12
# 437         A              Rene Bard        2016-07-12          2016-07-12
# 1552        A             Anna Bolin        2016-08-05          2016-08-15
# 13240       I             Anna Bolin        2016-08-05          2016-08-15
# 4142        I        JoAnn Hinkle-DA        2016-09-29                 NaT
# ...       ...                    ...               ...                 ...
# 113190      A            Kim Correll        2022-05-31          2022-06-08
# 93343       I     Jennifer Rose - ES        2022-05-31          2022-06-04
# 112947      A     Signal Centers-EEA        2022-05-31                 NaT
# 111777      A     Signal Centers-EEA        2022-05-31                 NaT
# 81090       I  Alicia Taylor - Admin        2022-05-31                 NaT
#
#         ... Latest IFSP Date                              Exit Reason  \
# 8367    ...              NaT                    Ineligible for Part C
# 437     ...              NaT                                      NaN
# 1552    ...              NaT                                      NaN
# 13240   ...              NaT  618 - Part B eligibility not determined
# 4142    ...              NaT               Referral less than 45 days
# ...     ...              ...                                      ...
# 113190  ...              NaT                                      NaN
# 93343   ...              NaT                    Ineligible for Part C
# 112947  ...              NaT                                      NaN
# 111777  ...              NaT                                      NaN
# 81090   ...              NaT                        Unable to contact
#
#         Exit Date Fiscal Year Notification Month Tenn Region Fiscal Year.1  \
# 8367   2016-08-25         NaN                NaN         NaN           NaN
# 437           NaT   2016-2017                Jul     Western        2016.0
# 1552          NaT   2016-2017                Aug      Middle        2016.0
# 13240  2016-12-03         NaN                NaN         NaN           NaN
# 4142   2016-09-29   2016-2017                Sep     Western        2016.0
# ...           ...         ...                ...         ...           ...
# 113190        NaT   2021-2022                May      Middle        2021.0
# 93343  2022-06-27         NaN                NaN         NaN           NaN
# 112947        NaT   2021-2022                May     Eastern        2021.0
# 111777        NaT   2021-2022                May     Eastern        2021.0
# 81090  2022-07-01         NaN                NaN         NaN           NaN
#
#         third DOB Late Referral  Qtr
# 8367          NaT           NaN  NaN
# 437    2016-11-13           NaN  1.0
# 1552   2016-12-04           NaN  1.0
# 13240         NaT           NaN  NaN
# 4142   2016-10-09           1.0  1.0
# ...           ...           ...  ...
# 113190 2025-03-15           NaN  4.0
# 93343         NaT           NaN  NaN
# 112947 2023-04-10           NaN  4.0
# 111777 2023-05-13           NaN  4.0
# 81090         NaT           NaN  NaN
#
# [138452 rows x 24 columns]

# %%
monthly_df2 = monthly_df.drop(columns = ['POE', 'DOB', 'County Name', 'County SES', 'Child Phase', 'Active', 'Service Coordinator', 
                                 'Parent Consent Date', 'Referral Source Type Name', 'Initial Eligibility', 'Initial Eligibility Date', 'Initial IFSP Date', 'Latest IFSP Date', 'Exit Reason', 'Exit Date',
                                 '2012 Child Count', '2013 Child Count', 'Service Coordinator Counter', 'Referral Count', 
                                 'Evaluation Count', 'Eligibility Count', 'IFSP Count', 'Child Count', ' QTR ', 
                                 'Referral Source Category'])
monthly_df2
# Out:
#         Child ID Notification Date Fiscal Year Notification Month Tenn Region  \
# 0         403339        2016-07-01   2016-2017                Jul     Eastern
# 1         404085        2016-07-01   2016-2017                Jul     Eastern
# 2         403623        2016-07-01   2016-2017                Jul     Eastern
# 3         404157        2016-07-01   2016-2017                Jul     Eastern
# 4         404154        2016-07-01   2016-2017                Jul     Eastern
# ...          ...               ...         ...                ...         ...
# 113251    528759        2022-05-16   2021-2022                May      Middle
# 113252    528534        2022-05-11   2021-2022                May      Middle
# 113253    528430        2022-05-10   2021-2022                May      Middle
# 113254    528253        2022-05-06   2021-2022                May      Middle
# 113255    528535        2022-05-11   2021-2022                May      Middle
#
#         Fiscal Year.1  third DOB  Late Referral  Qtr
# 0                2016 2017-08-09            NaN    1
# 1                2016 2016-07-31            1.0    1
# 2                2016 2019-02-05            NaN    1
# 3                2016 2018-12-06            NaN    1
# 4                2016 2018-04-18            NaN    1
# ...               ...        ...            ...  ...
# 113251           2021 2024-04-07            NaN    4
# 113252           2021 2025-03-13            NaN    4
# 113253           2021 2025-01-05            NaN    4
# 113254           2021 2023-09-12            NaN    4
# 113255           2021 2025-02-08            NaN    4
#
# [113256 rows x 9 columns]

# %%
merged = pd.merge(monthly_df2, referral_df, how = 'outer').sort_values(['Child ID'])
merged
# Out:
#         Child ID Notification Date Fiscal Year Notification Month Tenn Region  \
# 25415     104085        2018-01-20   2017-2018                Jan      Middle
# 2092      350065        2016-08-17   2016-2017                Aug      Middle
# 437       351755        2016-07-12   2016-2017                Jul     Western
# 3369      353800        2016-09-14   2016-2017                Sep     Eastern
# 1552      353805        2016-08-05   2016-2017                Aug      Middle
# ...          ...               ...         ...                ...         ...
# 114109    531592        2022-07-01         NaN                NaN         NaN
# 114352    531593        2022-07-01         NaN                NaN         NaN
# 114075    531594        2022-07-01         NaN                NaN         NaN
# 114046    531595        2022-07-01         NaN                NaN         NaN
# 114959    531596        2022-07-01         NaN                NaN         NaN
#
#         Fiscal Year.1  third DOB  Late Referral  Qtr POE  ... Active  \
# 25415          2017.0 2010-07-07            1.0  3.0  GN  ...      I
# 2092           2016.0 2016-10-15            1.0  1.0  UC  ...      I
# 437            2016.0 2016-11-13            NaN  1.0  NW  ...      I
# 3369           2016.0 2016-10-01            1.0  1.0  FT  ...      I
# 1552           2016.0 2016-12-04            NaN  1.0  UC  ...      I
# ...               ...        ...            ...  ...  ..  ...    ...
# 114109            NaN        NaT            NaN  NaN  GN  ...      A
# 114352            NaN        NaT            NaN  NaN  GN  ...      A
# 114075            NaN        NaT            NaN  NaN  GN  ...      A
# 114046            NaN        NaT            NaN  NaN  GN  ...      A
# 114959            NaN        NaT            NaN  NaN  SC  ...      A
#
#                  Service Coordinator Parent Consent Date  \
# 25415                            NaN                 NaT
# 2092                 Steven Scarlett                 NaT
# 437                        Rene Bard          2016-07-12
# 3369    Jennifer Terranera - 45 days                 NaT
# 1552                      Anna Bolin          2016-08-15
# ...                              ...                 ...
# 114109                   Kim Correll                 NaT
# 114352                   Kim Correll                 NaT
# 114075                   Kim Correll                 NaT
# 114046                   Kim Correll                 NaT
# 114959                   Kim Correll                 NaT
#
#          Referral Source Type Name Initial Eligibility  \
# 25415                          DCS                 NaN
# 2092                           PCP                 NaN
# 437                         Parent          Ineligible
# 3369                        Parent                 NaN
# 1552               Dept. of Health            Eligible
# ...                            ...                 ...
# 114109                         PCP                 NaN
# 114352                         PCP                 NaN
# 114075  Other Health Care Provider                 NaN
# 114046                    Hospital                 NaN
# 114959                         PCP                 NaN
#
#        Initial Eligibility Date Initial IFSP Date Latest IFSP Date  \
# 25415                       NaT               NaT              NaT
# 2092                        NaT               NaT              NaT
# 437                  2016-08-25               NaT              NaT
# 3369                        NaT               NaT              NaT
# 1552                 2016-10-05        2016-10-10              NaT
# ...                         ...               ...              ...
# 114109                      NaT               NaT              NaT
# 114352                      NaT               NaT              NaT
# 114075                      NaT               NaT              NaT
# 114046                      NaT               NaT              NaT
# 114959                      NaT               NaT              NaT
#
#                                     Exit Reason  Exit Date
# 25415                         Unable to contact 2010-01-25
# 2092                          Unable to contact 2016-08-31
# 437                       Ineligible for Part C 2016-08-25
# 3369                 Referral less than 45 days 2016-09-15
# 1552    618 - Part B eligibility not determined 2016-12-03
# ...                                         ...        ...
# 114109                                      NaN        NaT
# 114352                                      NaN        NaT
# 114075                                      NaN        NaT
# 114046                                      NaN        NaT
# 114959                                      NaN        NaT
#
# [115524 rows x 24 columns]

# %%
merged[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']] = merged[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']].apply(pd.to_datetime)
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115524 entries, 25415 to 114959
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Child ID                   115524 non-null  int64
#  1   Notification Date          115524 non-null  datetime64[ns]
#  2   Fiscal Year                113256 non-null  object
#  3   Notification Month         113256 non-null  object
#  4   Tenn Region                113256 non-null  object
#  5   Fiscal Year.1              113256 non-null  float64
#  6   third DOB                  113256 non-null  datetime64[ns]
#  7   Late Referral              2829 non-null    float64
#  8   Qtr                        113256 non-null  float64
#  9   POE                        96580 non-null   object
#  10  DOB                        96580 non-null   datetime64[ns]
#  11  County Name                96576 non-null   object
#  12  County SES                 96576 non-null   object
#  13  Child Phase                96580 non-null   object
#  14  Active                     96580 non-null   object
#  15  Service Coordinator        96579 non-null   object
#  16  Parent Consent Date        70026 non-null   datetime64[ns]
#  17  Referral Source Type Name  96580 non-null   object
#  18  Initial Eligibility        68221 non-null   object
#  19  Initial Eligibility Date   68221 non-null   datetime64[ns]
#  20  Initial IFSP Date          45493 non-null   datetime64[ns]
#  21  Latest IFSP Date           44331 non-null   datetime64[ns]
#  22  Exit Reason                85194 non-null   object
#  23  Exit Date                  85194 non-null   datetime64[ns]
# dtypes: datetime64[ns](8), float64(3), int64(1), object(12)
# memory usage: 22.0+ MB

# %%
teis_c3 = monthly_df.drop(columns = ['2012 Child Count', '2013 Child Count', 'Service Coordinator Counter', 'Referral Count', 
                                 'Evaluation Count', 'Eligibility Count', 'IFSP Count', 'Child Count', ' QTR ', 
                                 'Referral Source Category'])
teis_c3
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 0       ET    403339 2014-08-09      Blount  Transitional   Eligibility
# 1       FT    404085 2013-07-31      Unicoi       At-Risk  Notification
# 2       FT    403623 2016-02-05    Sullivan  Transitional   Eligibility
# 3       FT    404157 2015-12-06    Sullivan  Transitional          IFSP
# 4       FT    404154 2015-04-18     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759 2021-04-07      Sumner   Competitive    Evaluation
# 113252  UC    528534 2022-03-13      Sumner   Competitive          IFSP
# 113253  UC    528430 2022-01-05  Cumberland  Transitional   Eligibility
# 113254  UC    528253 2020-09-12      Sumner   Competitive          IFSP
# 113255  UC    528535 2022-02-08       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator Notification Date  \
# 0           A                  Kristi Borer        2016-07-01
# 1           I  Jennifer Terranera - 45 days        2016-07-01
# 2           A                   Amy Talbert        2016-07-01
# 3           A                Candice Cradic        2016-07-01
# 4           A                Kathy Jeffries        2016-07-01
# ...       ...                           ...               ...
# 113251      A             Sherry Roberts-DS        2022-05-16
# 113252      A                   Robyn Hogan        2022-05-11
# 113253      A                    Lisa Davis        2022-05-10
# 113254      A                    Taylor Lee        2022-05-06
# 113255      A             Sherry Roberts-DS        2022-05-11
#
#        Parent Consent Date  ... Latest IFSP Date                 Exit Reason  \
# 0               2016-07-01  ...              NaT                         NaN
# 1                      NaT  ...              NaT  Referral less than 45 days
# 2               2016-07-20  ...              NaT                         NaN
# 3               2016-07-22  ...       2016-08-10                         NaN
# 4               2016-07-18  ...       2016-07-28                         NaN
# ...                    ...  ...              ...                         ...
# 113251          2022-05-26  ...              NaT                         NaN
# 113252          2022-05-23  ...       2022-06-14                         NaN
# 113253          2022-05-18  ...              NaT                         NaN
# 113254          2022-05-11  ...       2022-05-31                         NaN
# 113255          2022-05-27  ...              NaT                         NaN
#
#         Exit Date Fiscal Year Notification Month Tenn Region Fiscal Year.1  \
# 0             NaT   2016-2017                Jul     Eastern          2016
# 1      2016-07-01   2016-2017                Jul     Eastern          2016
# 2             NaT   2016-2017                Jul     Eastern          2016
# 3             NaT   2016-2017                Jul     Eastern          2016
# 4             NaT   2016-2017                Jul     Eastern          2016
# ...           ...         ...                ...         ...           ...
# 113251        NaT   2021-2022                May      Middle          2021
# 113252        NaT   2021-2022                May      Middle          2021
# 113253        NaT   2021-2022                May      Middle          2021
# 113254        NaT   2021-2022                May      Middle          2021
# 113255        NaT   2021-2022                May      Middle          2021
#
#         third DOB Late Referral Qtr
# 0      2017-08-09           NaN   1
# 1      2016-07-31           1.0   1
# 2      2019-02-05           NaN   1
# 3      2018-12-06           NaN   1
# 4      2018-04-18           NaN   1
# ...           ...           ...  ..
# 113251 2024-04-07           NaN   4
# 113252 2025-03-13           NaN   4
# 113253 2025-01-05           NaN   4
# 113254 2023-09-12           NaN   4
# 113255 2025-02-08           NaN   4
#
# [113256 rows x 24 columns]

# %%
teis_c3[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']] = teis_c3[['DOB', 'Notification Date', 'Parent Consent Date', 'third DOB', 'Exit Date']].apply(pd.to_datetime)
teis_c3
# Out:
#        POE  Child ID        DOB County Name    County SES   Child Phase  \
# 0       ET    403339 2014-08-09      Blount  Transitional   Eligibility
# 1       FT    404085 2013-07-31      Unicoi       At-Risk  Notification
# 2       FT    403623 2016-02-05    Sullivan  Transitional   Eligibility
# 3       FT    404157 2015-12-06    Sullivan  Transitional          IFSP
# 4       FT    404154 2015-04-18     Hawkins       At-Risk          IFSP
# ...     ..       ...        ...         ...           ...           ...
# 113251  UC    528759 2021-04-07      Sumner   Competitive    Evaluation
# 113252  UC    528534 2022-03-13      Sumner   Competitive          IFSP
# 113253  UC    528430 2022-01-05  Cumberland  Transitional   Eligibility
# 113254  UC    528253 2020-09-12      Sumner   Competitive          IFSP
# 113255  UC    528535 2022-02-08       Smith  Transitional    Evaluation
#
#        Active           Service Coordinator Notification Date  \
# 0           A                  Kristi Borer        2016-07-01
# 1           I  Jennifer Terranera - 45 days        2016-07-01
# 2           A                   Amy Talbert        2016-07-01
# 3           A                Candice Cradic        2016-07-01
# 4           A                Kathy Jeffries        2016-07-01
# ...       ...                           ...               ...
# 113251      A             Sherry Roberts-DS        2022-05-16
# 113252      A                   Robyn Hogan        2022-05-11
# 113253      A                    Lisa Davis        2022-05-10
# 113254      A                    Taylor Lee        2022-05-06
# 113255      A             Sherry Roberts-DS        2022-05-11
#
#        Parent Consent Date  ... Latest IFSP Date                 Exit Reason  \
# 0               2016-07-01  ...              NaT                         NaN
# 1                      NaT  ...              NaT  Referral less than 45 days
# 2               2016-07-20  ...              NaT                         NaN
# 3               2016-07-22  ...       2016-08-10                         NaN
# 4               2016-07-18  ...       2016-07-28                         NaN
# ...                    ...  ...              ...                         ...
# 113251          2022-05-26  ...              NaT                         NaN
# 113252          2022-05-23  ...       2022-06-14                         NaN
# 113253          2022-05-18  ...              NaT                         NaN
# 113254          2022-05-11  ...       2022-05-31                         NaN
# 113255          2022-05-27  ...              NaT                         NaN
#
#         Exit Date Fiscal Year Notification Month Tenn Region Fiscal Year.1  \
# 0             NaT   2016-2017                Jul     Eastern          2016
# 1      2016-07-01   2016-2017                Jul     Eastern          2016
# 2             NaT   2016-2017                Jul     Eastern          2016
# 3             NaT   2016-2017                Jul     Eastern          2016
# 4             NaT   2016-2017                Jul     Eastern          2016
# ...           ...         ...                ...         ...           ...
# 113251        NaT   2021-2022                May      Middle          2021
# 113252        NaT   2021-2022                May      Middle          2021
# 113253        NaT   2021-2022                May      Middle          2021
# 113254        NaT   2021-2022                May      Middle          2021
# 113255        NaT   2021-2022                May      Middle          2021
#
#         third DOB Late Referral Qtr
# 0      2017-08-09           NaN   1
# 1      2016-07-31           1.0   1
# 2      2019-02-05           NaN   1
# 3      2018-12-06           NaN   1
# 4      2018-04-18           NaN   1
# ...           ...           ...  ..
# 113251 2024-04-07           NaN   4
# 113252 2025-03-13           NaN   4
# 113253 2025-01-05           NaN   4
# 113254 2023-09-12           NaN   4
# 113255 2025-02-08           NaN   4
#
# [113256 rows x 24 columns]

# %%
teis_merge2 = pd.merge(merged, teis_c3, on=['Child ID', 'Notification Date'], how='left')
teis_merge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115524 entries, 0 to 115523
# Data columns (total 46 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Child ID                     115524 non-null  int64
#  1   Notification Date            115524 non-null  datetime64[ns]
#  2   Fiscal Year_x                113256 non-null  object
#  3   Notification Month_x         113256 non-null  object
#  4   Tenn Region_x                113256 non-null  object
#  5   Fiscal Year.1_x              113256 non-null  float64
#  6   third DOB_x                  113256 non-null  datetime64[ns]
#  7   Late Referral_x              2829 non-null    float64
#  8   Qtr_x                        113256 non-null  float64
#  9   POE_x                        96580 non-null   object
#  10  DOB_x                        96580 non-null   datetime64[ns]
#  11  County Name_x                96576 non-null   object
#  12  County SES_x                 96576 non-null   object
#  13  Child Phase_x                96580 non-null   object
#  14  Active_x                     96580 non-null   object
#  15  Service Coordinator_x        96579 non-null   object
#  16  Parent Consent Date_x        70026 non-null   datetime64[ns]
#  17  Referral Source Type Name_x  96580 non-null   object
#  18  Initial Eligibility_x        68221 non-null   object
#  19  Initial Eligibility Date_x   68221 non-null   datetime64[ns]
#  20  Initial IFSP Date_x          45493 non-null   datetime64[ns]
#  21  Latest IFSP Date_x           44331 non-null   datetime64[ns]
#  22  Exit Reason_x                85194 non-null   object
#  23  Exit Date_x                  85194 non-null   datetime64[ns]
#  24  POE_y                        113256 non-null  object
#  25  DOB_y                        113256 non-null  datetime64[ns]
#  26  County Name_y                113251 non-null  object
#  27  County SES_y                 113251 non-null  object
#  28  Child Phase_y                113256 non-null  object
#  29  Active_y                     113256 non-null  object
#  30  Service Coordinator_y        113255 non-null  object
#  31  Parent Consent Date_y        58101 non-null   datetime64[ns]
#  32  Referral Source Type Name_y  113256 non-null  object
#  33  Initial Eligibility_y        40762 non-null   object
#  34  Initial Eligibility Date_y   40468 non-null   datetime64[ns]
#  35  Initial IFSP Date_y          7944 non-null    datetime64[ns]
#  36  Latest IFSP Date_y           7917 non-null    datetime64[ns]
#  37  Exit Reason_y                39366 non-null   object
#  38  Exit Date_y                  39121 non-null   datetime64[ns]
#  39  Fiscal Year_y                113256 non-null  object
#  40  Notification Month_y         113256 non-null  object
#  41  Tenn Region_y                113256 non-null  object
#  42  Fiscal Year.1_y              113256 non-null  float64
#  43  third DOB_y                  113256 non-null  datetime64[ns]
#  44  Late Referral_y              2829 non-null    float64
#  45  Qtr_y                        113256 non-null  float64
# dtypes: datetime64[ns](15), float64(6), int64(1), object(24)
# memory usage: 41.4+ MB

# %%
teis_merge2['Referral Source Type Name_x'] = teis_merge2['Referral Source Type Name_x'].fillna(teis_merge2['Referral Source Type Name_y'])
teis_merge2['Late Referral_x'] = teis_merge2['Late Referral_x'].fillna(teis_merge2['Late Referral_y'])
teis_merge2['Qtr_x'] = teis_merge2['Qtr_x'].fillna(teis_merge2['Qtr_y'])
teis_merge2['POE_x'] = teis_merge2['POE_x'].fillna(teis_merge2['POE_y'])
teis_merge2['DOB_x'] = teis_merge2['DOB_x'].fillna(teis_merge2['DOB_y'])
teis_merge2['County Name_x'] = teis_merge2['County Name_x'].fillna(teis_merge2['County Name_y'])
teis_merge2['County SES_x'] = teis_merge2['County SES_x'].fillna(teis_merge2['County SES_y'])
teis_merge2['Child Phase_x'] = teis_merge2['Child Phase_x'].fillna(teis_merge2['Child Phase_y'])
teis_merge2['Service Coordinator_x'] = teis_merge2['Service Coordinator_x'].fillna(teis_merge2['Service Coordinator_y'])
teis_merge2['Parent Consent Date_x'] = teis_merge2['Parent Consent Date_x'].fillna(teis_merge2['Parent Consent Date_y'])
teis_merge2['Initial Eligibility_x'] = teis_merge2['Initial Eligibility_x'].fillna(teis_merge2['Initial Eligibility_y'])
teis_merge2['Initial Eligibility Date_x'] = teis_merge2['Initial Eligibility Date_x'].fillna(teis_merge2['Initial Eligibility Date_y'])
teis_merge2['Initial IFSP Date_x'] = teis_merge2['Initial IFSP Date_x'].fillna(teis_merge2['Initial IFSP Date_y'])
teis_merge2['Latest IFSP Date_x'] = teis_merge2['Latest IFSP Date_x'].fillna(teis_merge2['Latest IFSP Date_y'])
teis_merge2['Exit Reason_x'] = teis_merge2['Exit Reason_x'].fillna(teis_merge2['Exit Reason_y'])
teis_merge2['Exit Date_x'] = teis_merge2['Exit Date_x'].fillna(teis_merge2['Exit Date_x'])
teis_merge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115524 entries, 0 to 115523
# Data columns (total 46 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Child ID                     115524 non-null  int64
#  1   Notification Date            115524 non-null  datetime64[ns]
#  2   Fiscal Year_x                113256 non-null  object
#  3   Notification Month_x         113256 non-null  object
#  4   Tenn Region_x                113256 non-null  object
#  5   Fiscal Year.1_x              113256 non-null  float64
#  6   third DOB_x                  113256 non-null  datetime64[ns]
#  7   Late Referral_x              2829 non-null    float64
#  8   Qtr_x                        113256 non-null  float64
#  9   POE_x                        115524 non-null  object
#  10  DOB_x                        115524 non-null  datetime64[ns]
#  11  County Name_x                115520 non-null  object
#  12  County SES_x                 115520 non-null  object
#  13  Child Phase_x                115524 non-null  object
#  14  Active_x                     96580 non-null   object
#  15  Service Coordinator_x        115523 non-null  object
#  16  Parent Consent Date_x        75365 non-null   datetime64[ns]
#  17  Referral Source Type Name_x  115524 non-null  object
#  18  Initial Eligibility_x        71884 non-null   object
#  19  Initial Eligibility Date_x   71861 non-null   datetime64[ns]
#  20  Initial IFSP Date_x          45520 non-null   datetime64[ns]
#  21  Latest IFSP Date_x           44539 non-null   datetime64[ns]
#  22  Exit Reason_x                96177 non-null   object
#  23  Exit Date_x                  85194 non-null   datetime64[ns]
#  24  POE_y                        113256 non-null  object
#  25  DOB_y                        113256 non-null  datetime64[ns]
#  26  County Name_y                113251 non-null  object
#  27  County SES_y                 113251 non-null  object
#  28  Child Phase_y                113256 non-null  object
#  29  Active_y                     113256 non-null  object
#  30  Service Coordinator_y        113255 non-null  object
#  31  Parent Consent Date_y        58101 non-null   datetime64[ns]
#  32  Referral Source Type Name_y  113256 non-null  object
#  33  Initial Eligibility_y        40762 non-null   object
#  34  Initial Eligibility Date_y   40468 non-null   datetime64[ns]
#  35  Initial IFSP Date_y          7944 non-null    datetime64[ns]
#  36  Latest IFSP Date_y           7917 non-null    datetime64[ns]
#  37  Exit Reason_y                39366 non-null   object
#  38  Exit Date_y                  39121 non-null   datetime64[ns]
#  39  Fiscal Year_y                113256 non-null  object
#  40  Notification Month_y         113256 non-null  object
#  41  Tenn Region_y                113256 non-null  object
#  42  Fiscal Year.1_y              113256 non-null  float64
#  43  third DOB_y                  113256 non-null  datetime64[ns]
#  44  Late Referral_y              2829 non-null    float64
#  45  Qtr_y                        113256 non-null  float64
# dtypes: datetime64[ns](15), float64(6), int64(1), object(24)
# memory usage: 41.4+ MB

# %%
teis_merge2 = teis_merge2.drop(columns = ['POE_y', 'DOB_y', 'County Name_y', 'County SES_y', 'Child Phase_y', 'Active_y',
                                          'Service Coordinator_y', 'Parent Consent Date_y', 'Referral Source Type Name_y', 
                                          'Initial Eligibility_y', 'Initial Eligibility Date_y', 'Initial IFSP Date_y',
                                          'Latest IFSP Date_y', 'Exit Reason_y', 'Exit Date_y', 'Fiscal Year_y',
                                          'Notification Month_y', 'Tenn Region_y', 'Fiscal Year.1_y', 'third DOB_y', 
                                          'Late Referral_y', 'Qtr_y'])

# %%
teis_merge2 = teis_merge2.rename(columns= {'Fiscal Year_x': 'Fiscal Year',
                                           'Notification Month_x' : 'Notification Month', 
                                           'Tenn Region_x' : 'Tenn Region', 
                                           'Fiscal Year.1_x' : 'Fiscal Year.1',
                                           'third DOB_x' : 'third_DOB',
                                           'Late Referral_x' : 'Late Referral',
                                           'Qtr_x' : 'Qtr',
                                           'POE_x' : 'POE',
                                           'DOB_x' : 'DOB',
                                           'County Name_x' : 'County Name',
                                           'County SES_x' : 'County SES',
                                           'Child Phase_x' : 'Child Phase',
                                           'Active_x' : 'Active',
                                           'Service Coordinator_x' : 'Service Coordinator',
                                           'Parent Consent Date_x' : 'Parent Consent',
                                           'Referral Source Type Name_x' : 'Referral Source Type Name',
                                           'Initial Eligibility_x' : 'Initial Eligibility',
                                           'Initial Eligibility Date_x' : 'Initial Eligibility Date',
                                           'Initial IFSP Date_x' : 'Initial IFSP Date',
                                           'Latest IFSP Date_x' : 'Latest IFSP',
                                           'Exit Reason_x' : 'Exit Reason',
                                           'Exit Date_x' : 'Exit Date'})
teis_merge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115524 entries, 0 to 115523
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Child ID                   115524 non-null  int64
#  1   Notification Date          115524 non-null  datetime64[ns]
#  2   Fiscal Year                113256 non-null  object
#  3   Notification Month         113256 non-null  object
#  4   Tenn Region                113256 non-null  object
#  5   Fiscal Year.1              113256 non-null  float64
#  6   third_DOB                  113256 non-null  datetime64[ns]
#  7   Late Referral              2829 non-null    float64
#  8   Qtr                        113256 non-null  float64
#  9   POE                        115524 non-null  object
#  10  DOB                        115524 non-null  datetime64[ns]
#  11  County Name                115520 non-null  object
#  12  County SES                 115520 non-null  object
#  13  Child Phase                115524 non-null  object
#  14  Active                     96580 non-null   object
#  15  Service Coordinator        115523 non-null  object
#  16  Parent Consent             75365 non-null   datetime64[ns]
#  17  Referral Source Type Name  115524 non-null  object
#  18  Initial Eligibility        71884 non-null   object
#  19  Initial Eligibility Date   71861 non-null   datetime64[ns]
#  20  Initial IFSP Date          45520 non-null   datetime64[ns]
#  21  Latest IFSP                44539 non-null   datetime64[ns]
#  22  Exit Reason                96177 non-null   object
#  23  Exit Date                  85194 non-null   datetime64[ns]
# dtypes: datetime64[ns](8), float64(3), int64(1), object(12)
# memory usage: 22.0+ MB

# %%
teis_merge2['Year'] = teis_merge2['Notification Date'].dt.year
teis_merge2.head(2)
# Out:
#    Child ID Notification Date Fiscal Year Notification Month Tenn Region  \
# 0    104085        2018-01-20   2017-2018                Jan      Middle
# 1    350065        2016-08-17   2016-2017                Aug      Middle
#
#    Fiscal Year.1  third_DOB  Late Referral  Qtr POE  ... Service Coordinator  \
# 0         2017.0 2010-07-07            1.0  3.0  GN  ...                 NaN
# 1         2016.0 2016-10-15            1.0  1.0  UC  ...     Steven Scarlett
#
#   Parent Consent Referral Source Type Name Initial Eligibility  \
# 0            NaT                       DCS                 NaN
# 1            NaT                       PCP                 NaN
#
#   Initial Eligibility Date Initial IFSP Date Latest IFSP        Exit Reason  \
# 0                      NaT               NaT         NaT  Unable to contact
# 1                      NaT               NaT         NaT  Unable to contact
#
#    Exit Date  Year
# 0 2010-01-25  2018
# 1 2016-08-31  2016
#
# [2 rows x 25 columns]

# %%
all_dups2 = teis_merge2[teis_merge2.duplicated(['Child ID', 'Notification Date'], keep=False)].sort_values('Child ID')
all_dups2
#making sure that there aren't any unanticipated duplicates
# Out:
# Empty DataFrame
# Columns: [Child ID, Notification Date, Fiscal Year, Notification Month, Tenn Region, Fiscal Year.1, third_DOB, Late Referral, Qtr, POE, DOB, County Name, County SES, Child Phase, Active, Service Coordinator, Parent Consent, Referral Source Type Name, Initial Eligibility, Initial Eligibility Date, Initial IFSP Date, Latest IFSP, Exit Reason, Exit Date, Year]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ### Add Age Column

# %%
teis_merge2['Age'] = (teis_merge2['Notification Date'] - teis_merge2['DOB']).dt.days / 365
teis_merge2['Age (Months)'] = (teis_merge2['Notification Date'] - teis_merge2['DOB']).dt.days/ 12
teis_merge2
# Out:
#         Child ID Notification Date Fiscal Year Notification Month Tenn Region  \
# 0         104085        2018-01-20   2017-2018                Jan      Middle
# 1         350065        2016-08-17   2016-2017                Aug      Middle
# 2         351755        2016-07-12   2016-2017                Jul     Western
# 3         353800        2016-09-14   2016-2017                Sep     Eastern
# 4         353805        2016-08-05   2016-2017                Aug      Middle
# ...          ...               ...         ...                ...         ...
# 115519    531592        2022-07-01         NaN                NaN         NaN
# 115520    531593        2022-07-01         NaN                NaN         NaN
# 115521    531594        2022-07-01         NaN                NaN         NaN
# 115522    531595        2022-07-01         NaN                NaN         NaN
# 115523    531596        2022-07-01         NaN                NaN         NaN
#
#         Fiscal Year.1  third_DOB  Late Referral  Qtr POE  ...  \
# 0              2017.0 2010-07-07            1.0  3.0  GN  ...
# 1              2016.0 2016-10-15            1.0  1.0  UC  ...
# 2              2016.0 2016-11-13            NaN  1.0  NW  ...
# 3              2016.0 2016-10-01            1.0  1.0  FT  ...
# 4              2016.0 2016-12-04            NaN  1.0  UC  ...
# ...               ...        ...            ...  ...  ..  ...
# 115519            NaN        NaT            NaN  NaN  GN  ...
# 115520            NaN        NaT            NaN  NaN  GN  ...
# 115521            NaN        NaT            NaN  NaN  GN  ...
# 115522            NaN        NaT            NaN  NaN  GN  ...
# 115523            NaN        NaT            NaN  NaN  SC  ...
#
#          Referral Source Type Name Initial Eligibility  \
# 0                              DCS                 NaN
# 1                              PCP                 NaN
# 2                           Parent          Ineligible
# 3                           Parent                 NaN
# 4                  Dept. of Health            Eligible
# ...                            ...                 ...
# 115519                         PCP                 NaN
# 115520                         PCP                 NaN
# 115521  Other Health Care Provider                 NaN
# 115522                    Hospital                 NaN
# 115523                         PCP                 NaN
#
#        Initial Eligibility Date Initial IFSP Date Latest IFSP  \
# 0                           NaT               NaT         NaT
# 1                           NaT               NaT         NaT
# 2                    2016-08-25               NaT         NaT
# 3                           NaT               NaT         NaT
# 4                    2016-10-05        2016-10-10         NaT
# ...                         ...               ...         ...
# 115519                      NaT               NaT         NaT
# 115520                      NaT               NaT         NaT
# 115521                      NaT               NaT         NaT
# 115522                      NaT               NaT         NaT
# 115523                      NaT               NaT         NaT
#
#                                     Exit Reason  Exit Date  Year        Age  \
# 0                             Unable to contact 2010-01-25  2018  10.547945
# 1                             Unable to contact 2016-08-31  2016   2.841096
# 2                         Ineligible for Part C 2016-08-25  2016   2.663014
# 3                    Referral less than 45 days 2016-09-15  2016   2.956164
# 4       618 - Part B eligibility not determined 2016-12-03  2016   2.671233
# ...                                         ...        ...   ...        ...
# 115519                                      NaN        NaT  2022   2.115068
# 115520                                      NaN        NaT  2022   0.564384
# 115521                                      NaN        NaT  2022   0.027397
# 115522                                      NaN        NaT  2022   0.038356
# 115523                                      NaN        NaT  2022   2.515068
#
#        Age (Months)
# 0        320.833333
# 1         86.416667
# 2         81.000000
# 3         89.916667
# 4         81.250000
# ...             ...
# 115519    64.333333
# 115520    17.166667
# 115521     0.833333
# 115522     1.166667
# 115523    76.500000
#
# [115524 rows x 27 columns]

# %% [markdown]
# ## Masking

# %%
monthly_et = monthly_df.loc[monthly_df['POE'] == 'ET']
monthly_ft = monthly_df.loc[monthly_df['POE'] == 'FT']
monthly_gn = monthly_df.loc[monthly_df['POE'] == 'GN']
monthly_md = monthly_df.loc[monthly_df['POE'] == 'MD']
monthly_nw = monthly_df.loc[monthly_df['POE'] == 'NW']
monthly_sc = monthly_df.loc[monthly_df['POE'] == 'SC']
monthly_se = monthly_df.loc[monthly_df['POE'] == 'SE']
monthly_sw = monthly_df.loc[monthly_df['POE'] == 'SW']
monthly_uc = monthly_df.loc[monthly_df['POE'] == 'UC']

# %%
referral_et = referral_df.loc[referral_df['POE'] == 'ET']
referral_ft = referral_df.loc[referral_df['POE'] == 'FT']
referral_gn = referral_df.loc[referral_df['POE'] == 'GN']
referral_md = referral_df.loc[referral_df['POE'] == 'MD']
referral_nw = referral_df.loc[referral_df['POE'] == 'NW']
referral_sc = referral_df.loc[referral_df['POE'] == 'SC']
referral_se = referral_df.loc[referral_df['POE'] == 'SE']
referral_sw = referral_df.loc[referral_df['POE'] == 'SW']
referral_uc = referral_df.loc[referral_df['POE'] == 'UC']

# %%
#monthly_et['Age'] = (monthly_et['Notification/ Referral Date'] - monthly_et['DOB']).dt.days

# %%
active = referral_df[referral_df['Active'] == 'A']
active
# Out:
#       POE  Child ID        DOB County Name    County SES Child Phase Active  \
# 44490  ET    473470 2019-10-17      Blount  Transitional        IFSP      A
# 44492  ET    471077 2019-09-01      Blount  Transitional        IFSP      A
# 44497  ET    471127 2019-07-07        Knox  Transitional        IFSP      A
# 44566  ET    473709 2019-11-01    Grainger       At-Risk        IFSP      A
# 44630  ET    473817 2019-07-30        Knox  Transitional        IFSP      A
# ...    ..       ...        ...         ...           ...         ...    ...
# 96572  UC    523485 2019-10-23      Sumner   Competitive        IFSP      A
# 96573  UC    528430 2022-01-05  Cumberland  Transitional        IFSP      A
# 96574  UC    515685 2019-08-14      Sumner   Competitive        IFSP      A
# 96576  UC    528253 2020-09-12      Sumner   Competitive        IFSP      A
# 96578  UC    528535 2022-02-08       Smith  Transitional  Evaluation      A
#
#       Service Coordinator Notification Date Parent Consent Date  \
# 44490     Tiffany Robbins        2019-11-18          2019-12-12
# 44492     Tiffany Robbins        2019-11-18          2019-11-18
# 44497     Jackie Campbell        2019-10-08          2019-10-15
# 44566    Elizabeth Mounts        2019-11-21          2019-11-26
# 44630         Sandi Foust        2019-11-22          2019-12-02
# ...                   ...               ...                 ...
# 96572     Miriam Espinosa        2022-03-02          2022-03-10
# 96573          Lisa Davis        2022-05-10          2022-05-18
# 96574       Cindy Willard        2021-12-01          2021-12-07
# 96576          Taylor Lee        2022-05-06          2022-05-11
# 96578   Sherry Roberts-DS        2022-05-11          2022-05-27
#
#       Referral Source Type Name Initial Eligibility Initial Eligibility Date  \
# 44490                       DCS            Eligible               2019-12-17
# 44492                    Parent            Eligible               2019-10-25
# 44497                     Other            Eligible               2019-10-16
# 44566                       DCS            Eligible               2019-12-09
# 44630                    Parent            Eligible               2019-12-05
# ...                         ...                 ...                      ...
# 96572                       PCP            Eligible               2022-05-11
# 96573                    Parent            Eligible               2022-06-07
# 96574                    Parent            Eligible               2022-01-20
# 96576                       PCP            Eligible               2022-05-23
# 96578                    Parent                 NaN                      NaT
#
#       Initial IFSP Date Latest IFSP Date Exit Reason Exit Date
# 44490        2020-01-10       2022-06-06         NaN       NaT
# 44492        2019-12-12       2022-06-06         NaN       NaT
# 44497        2019-11-14       2022-06-01         NaN       NaT
# 44566        2019-12-23       2022-05-20         NaN       NaT
# 44630        2019-12-18       2022-05-13         NaN       NaT
# ...                 ...              ...         ...       ...
# 96572        2022-05-18       2022-06-08         NaN       NaT
# 96573        2022-06-21       2022-06-21         NaN       NaT
# 96574        2022-01-26       2022-06-21         NaN       NaT
# 96576        2022-05-31       2022-05-31         NaN       NaT
# 96578               NaT              NaT         NaN       NaT
#
# [11390 rows x 17 columns]

# %% [markdown]
# # What is the rate of re-referral?

# %%
# Duplicated Child IDs
reref = (monthly_df['Child ID'].value_counts() > 1).sum()
reref
# Out:
# 15267

# %%
# Sum of total Child IDs
num_children = pd.concat([monthly_df['Child ID'], referral_df['Child ID']], axis = 0).nunique()
num_children
# Out:
# 96743

# %%
# Divide Duplicated Child IDs by Sum of total Child IDs
perc_reref = str(round(((reref / num_children) * 100), 2)) + '%'
perc_reref
# Out:
# '15.78%'

# %% [markdown]
# #### Rate of re-referral for East Tennessee

# %%
# Duplicated Child IDs
east_reref = (monthly_et['Child ID'].value_counts() > 1).sum()
east_reref
# Out:
# 2770

# %%
# Sum of total Child IDs
east_num_children = pd.concat([monthly_et['Child ID'], referral_et['Child ID']], axis = 0).nunique()
east_num_children
# Out:
# 17414

# %%
# Divide Duplicated Child IDs by Sum of total Child IDs
et_reref = str(round(((east_reref / east_num_children) * 100), 2)) + '%'
et_reref
# Out:
# '15.91%'

# %% [markdown]
# #### Rate of referral for First Tennessee

# %%
ft_reref = (monthly_ft['Child ID'].value_counts() > 1).sum()

# %%
ft_num_children = pd.concat([monthly_ft['Child ID'], referral_ft['Child ID']], axis = 0).nunique()

# %%
ft_reref_perc = str(round(((ft_reref / ft_num_children) * 100), 2)) + '%'
ft_reref_perc
# Out:
# '15.46%'

# %% [markdown]
# #### Rate of re-referral for Greater Nashville

# %%
gn_reref = (monthly_gn['Child ID'].value_counts() > 1).sum()

# %%
gn_num_children = pd.concat([monthly_gn['Child ID'], referral_gn['Child ID']], axis = 0).nunique()

# %%
gn_reref_perc = str(round(((gn_reref / gn_num_children) * 100), 2)) + '%'
gn_reref_perc
# Out:
# '15.36%'

# %% [markdown]
# #### Rate of referral for Memphis Delta

# %%
md_reref = (monthly_md['Child ID'].value_counts() > 1).sum()

# %%
md_num_children = pd.concat([monthly_md['Child ID'], referral_md['Child ID']], axis = 0).nunique()

# %%
md_reref_perc = str(round(((md_reref / md_num_children) * 100), 2)) + '%'
md_reref_perc
# Out:
# '17.25%'

# %% [markdown]
# #### Rate of re-referral for Northwest

# %%
nw_reref = (monthly_nw['Child ID'].value_counts() > 1).sum()

# %%
nw_num_children = pd.concat([monthly_nw['Child ID'], referral_nw['Child ID']], axis = 0).nunique()

# %%
nw_reref_perc = str(round(((nw_reref / nw_num_children) * 100), 2)) + '%'
nw_reref_perc
# Out:
# '15.21%'

# %% [markdown]
# #### Rate of re-referral for South Central

# %%
sc_reref = (monthly_sc['Child ID'].value_counts() > 1).sum()

# %%
sc_num_children = pd.concat([monthly_sc['Child ID'], referral_sc['Child ID']], axis = 0).nunique()

# %%
sc_reref_perc = str(round(((sc_reref / sc_num_children) * 100), 2)) + '%'
sc_reref_perc
# Out:
# '13.31%'

# %% [markdown]
# #### Rate of re-referral for Southeast

# %%
se_reref = (monthly_se['Child ID'].value_counts() > 1).sum()

# %%
se_num_children = pd.concat([monthly_se['Child ID'], referral_se['Child ID']], axis = 0).nunique()

# %%
se_reref_perc = str(round(((se_reref / se_num_children) * 100), 2)) + '%'
se_reref_perc
# Out:
# '11.79%'

# %% [markdown]
# #### Rate of re-referral for Southwest

# %%
sw_reref = (monthly_sw['Child ID'].value_counts() > 1).sum()

# %%
sw_num_children = pd.concat([monthly_sw['Child ID'], referral_sw['Child ID']], axis = 0).nunique()

# %%
sw_reref_perc = str(round(((sw_reref / sw_num_children) * 100), 2)) + '%'
sw_reref_perc
# Out:
# '14.01%'

# %% [markdown]
# #### Rate of re-referral for Upper Cumberland

# %%
uc_reref = (monthly_uc['Child ID'].value_counts() > 1).sum()

# %%
uc_num_children = pd.concat([monthly_uc['Child ID'], referral_uc['Child ID']], axis = 0).nunique()

# %%
uc_reref_perc = str(round(((uc_reref / uc_num_children) * 100), 2)) + '%'
uc_reref_perc
# Out:
# '12.89%'

# %% [markdown]
# ### All POE re-referral rates

# %%
print('Total re-referral rate: ' + perc_reref)
print('East Tennessee re-referral rate: ' + et_reref)
print('First Tennessee re-referral rate: ' + ft_reref_perc)
print('Greater Nashville re-referral rate: ' + gn_reref_perc)
print('Memphis Delta re-referral rate: ' + md_reref_perc)
print('Northwest re-referral rate: ' + nw_reref_perc)
print('South Central re-referral rate: ' + sc_reref_perc)
print('Southeast re-referral rate: ' + se_reref_perc)
print('Southwest re-referral rate: ' + sw_reref_perc)
print('Upper Cumberland re-referral rate: ' + uc_reref_perc)
# Out:
# Total re-referral rate: 15.78%
# East Tennessee re-referral rate: 15.91%
# First Tennessee re-referral rate: 15.46%
# Greater Nashville re-referral rate: 15.36%
# Memphis Delta re-referral rate: 17.25%
# Northwest re-referral rate: 15.21%
# South Central re-referral rate: 13.31%
# Southeast re-referral rate: 11.79%
# Southwest re-referral rate: 14.01%
# Upper Cumberland re-referral rate: 12.89%

# %%
teis_merge2_reref = (teis_merge2['Child ID'].value_counts() > 1).sum()
teis_merge2_reref
# Out:
# 15641

# %%
teis_merge2_num_children = teis_merge2['Child ID'].nunique()
teis_merge2_num_children
# Out:
# 96743

# %%
teis_merge2_perc = str(round(((teis_merge2_reref / teis_merge2_num_children) * 100), 2)) + '%'
teis_merge2_perc
# Out:
# '16.17%'

# %% [markdown]
# # Referral sources with higher rates of successful referrals

# %%
final_data['Success'] = (final_data['Initial IFSP Date'].notna()) | (final_data['Child Phase'] == 'IFSP')

# %%
final_data['Success'].mean()
# Out:
# 0.39403067760811605

# %%
referral_source = final_data['Referral Source Type Name'].value_counts()

# %%
success = final_data[(final_data['Initial IFSP Date'].notna()) | (final_data['Child Phase'] == 'IFSP')]
referral_success = success['Referral Source Type Name'].value_counts()

# %%
merged_referral_source = pd.concat([referral_success, referral_source], axis = 1, join = 'inner')
merged_referral_source.columns = ['Successful Referral Count', 'Total Referral Count']
merged_referral_source['Success Rate'] = round((merged_referral_source['Successful Referral Count'] / merged_referral_source['Total Referral Count']) * 100, 2)
merged_referral_source = merged_referral_source.reset_index()
merged_referral_source
# Out:
#                             index  Successful Referral Count  \
# 0                             PCP                      18264
# 1                          Parent                      12595
# 2                             DCS                       4510
# 3                        Hospital                       2916
# 4                 Dept. of Health                       1375
# 5                           Other                       1184
# 6                            NICU                       1158
# 7      Other Health Care Provider                       1146
# 8     Early Head Start/Head Start                        423
# 9                Speech Therapist                        395
# 10                             PT                        375
# 11             Family and Friends                        274
# 12                  Foster Parent                        262
# 13            Child Care provider                        179
# 14                           EIRA                        169
# 15  Community/Child Find Activity                        155
# 16                            NHS                         69
# 17                             OT                         44
# 18                           PICU                         15
# 19                            LEA                          6
# 20                            DHS                          3
# 21                           TIPS                          2
# 22                           DMRS                          1
#
#     Total Referral Count  Success Rate
# 0                  43899         41.60
# 1                  21944         57.40
# 2                  25721         17.53
# 3                   7292         39.99
# 4                   3675         37.41
# 5                   2612         45.33
# 6                   3275         35.36
# 7                   2326         49.27
# 8                   1025         41.27
# 9                    654         60.40
# 10                   623         60.19
# 11                   516         53.10
# 12                   421         62.23
# 13                   434         41.24
# 14                   351         48.15
# 15                   386         40.16
# 16                   222         31.08
# 17                    86         51.16
# 18                    26         57.69
# 19                    16         37.50
# 20                    13         23.08
# 21                     4         50.00
# 22                     1        100.00

# %%
merged_referral_source = merged_referral_source.sort_values(by = 'Total Referral Count', ascending = False)
merged_referral_source = merged_referral_source.rename(columns = {'index': 'Referral Source'})
merged_referral_source
# Out:
#                   Referral Source  Successful Referral Count  \
# 0                             PCP                      18264
# 2                             DCS                       4510
# 1                          Parent                      12595
# 3                        Hospital                       2916
# 4                 Dept. of Health                       1375
# 6                            NICU                       1158
# 5                           Other                       1184
# 7      Other Health Care Provider                       1146
# 8     Early Head Start/Head Start                        423
# 9                Speech Therapist                        395
# 10                             PT                        375
# 11             Family and Friends                        274
# 13            Child Care provider                        179
# 12                  Foster Parent                        262
# 15  Community/Child Find Activity                        155
# 14                           EIRA                        169
# 16                            NHS                         69
# 17                             OT                         44
# 18                           PICU                         15
# 19                            LEA                          6
# 20                            DHS                          3
# 21                           TIPS                          2
# 22                           DMRS                          1
#
#     Total Referral Count  Success Rate
# 0                  43899         41.60
# 2                  25721         17.53
# 1                  21944         57.40
# 3                   7292         39.99
# 4                   3675         37.41
# 6                   3275         35.36
# 5                   2612         45.33
# 7                   2326         49.27
# 8                   1025         41.27
# 9                    654         60.40
# 10                   623         60.19
# 11                   516         53.10
# 13                   434         41.24
# 12                   421         62.23
# 15                   386         40.16
# 14                   351         48.15
# 16                   222         31.08
# 17                    86         51.16
# 18                    26         57.69
# 19                    16         37.50
# 20                    13         23.08
# 21                     4         50.00
# 22                     1        100.00

# %%
fig, ax = plt.subplots(figsize =(16, 9))
 
# Horizontal Bar Plot
ax.barh(merged_referral_source['Referral Source'], merged_referral_source['Success Rate'])
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for counter, i in enumerate(ax.patches):
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             #str(round((i.get_width()), 2)),
             str(merged_referral_source['Total Referral Count'].values[counter]),
             fontsize = 10, fontweight ='bold',
             color ='black')
 
# Add Plot Title
ax.set_title('Successful Referral Rate per Referral Source',
             loc ='left', );

# %%
merged_referral_source.sort_values(by = 'Success Rate', ascending = False).plot(x='Referral Source', y = ['Total Referral Count', 'Successful Referral Count'], kind = 'bar', figsize = (15,10), stacked = True, width = .7);

# %%
merged_referral_source.sort_values(by = 'Total Referral Count', ascending = True).plot(x='Referral Source',
                                                                                       y = ['Total Referral Count', 
                                                                                            'Successful Referral Count'], 
                                                                                       kind = 'barh', figsize = (15,10), 
                                                                                       stacked = True, width = .7)
plt.ylabel(None);

# %% [markdown]
# ## POE average age of referral

# %%
whos% DataFrame
# Out:
# Variable                 Type         Data/Info
# -----------------------------------------------
# active                   DataFrame          POE  Child ID      <...>[11390 rows x 17 columns]
# all_dups2                DataFrame    Empty DataFrame\nColumns:<...>\n\n[0 rows x 25 columns]
# all_teis_dups            DataFrame           POE  Child ID     <...>138452 rows x 24 columns]
# final_data               DataFrame            Child ID Notifica<...>115524 rows x 26 columns]
# full_teis                DataFrame          POE  Child ID      <...>209836 rows x 34 columns]
# merge                    DataFrame           POE  Child ID     <...>184750 rows x 34 columns]
# merged                   DataFrame            Child ID Notifica<...>115524 rows x 24 columns]
# merged_referral_source   DataFrame                      Referra<...>        1        100.00
# monthly_df               DataFrame           POE  Child ID     <...>113256 rows x 34 columns]
# monthly_df2              DataFrame            Child ID Notifica<...>[113256 rows x 9 columns]
# monthly_et               DataFrame           POE  Child ID     <...>[20226 rows x 34 columns]
# monthly_ft               DataFrame           POE  Child ID     <...>[11143 rows x 34 columns]
# monthly_gn               DataFrame           POE  Child ID     <...>[19956 rows x 34 columns]
# monthly_md               DataFrame           POE  Child ID     <...>[17261 rows x 34 columns]
# monthly_nw               DataFrame           POE  Child ID     <...>n[6506 rows x 34 columns]
# monthly_sc               DataFrame           POE  Child ID     <...>[14532 rows x 34 columns]
# monthly_se               DataFrame           POE  Child ID     <...>n[8575 rows x 34 columns]
# monthly_sw               DataFrame           POE  Child ID     <...>n[6034 rows x 34 columns]
# monthly_uc               DataFrame           POE  Child ID     <...>n[9023 rows x 34 columns]
# referral_df              DataFrame          POE  Child ID      <...>[96580 rows x 17 columns]
# referral_et              DataFrame          POE  Child ID      <...>[17123 rows x 17 columns]
# referral_ft              DataFrame          POE  Child ID      <...>n[9450 rows x 17 columns]
# referral_gn              DataFrame          POE  Child ID      <...>[16630 rows x 17 columns]
# referral_md              DataFrame          POE  Child ID      <...>[14365 rows x 17 columns]
# referral_nw              DataFrame          POE  Child ID      <...>n[5468 rows x 17 columns]
# referral_sc              DataFrame          POE  Child ID      <...>[12789 rows x 17 columns]
# referral_se              DataFrame          POE  Child ID      <...>n[7655 rows x 17 columns]
# referral_sw              DataFrame          POE  Child ID      <...>n[5205 rows x 17 columns]
# referral_uc              DataFrame          POE  Child ID      <...>n[7895 rows x 17 columns]
# success                  DataFrame            Child ID Notifica<...>[45520 rows x 26 columns]
# teis_c3                  DataFrame           POE  Child ID     <...>113256 rows x 24 columns]
# teis_clean               DataFrame          POE  Child ID      <...>184750 rows x 24 columns]
# teis_merge2              DataFrame            Child ID Notifica<...>115524 rows x 27 columns]

# %%
referral_et.columns
# Out:
# Index(['POE', 'Child ID', 'DOB', 'County Name', 'County SES', 'Child Phase',
#        'Active', 'Service Coordinator', 'Notification Date',
#        'Parent Consent Date', 'Referral Source Type Name',
#        'Initial Eligibility', 'Initial Eligibility Date', 'Initial IFSP Date',
#        'Latest IFSP Date', 'Exit Reason', 'Exit Date'],
#       dtype='object')

# %%
referral_et['Age'] = (referral_et['Notification Date'] - referral_et['DOB'])
# Out:
# <ipython-input-76-4312dfbabd51>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   referral_et['Age'] = (referral_et['Notification Date'] - referral_et['DOB'])

# %%
et_avg_age = referral_et['Age'].mean()

# %%
referral_ft['Age'] = (referral_ft['Notification Date'] - referral_ft['DOB'])
# Out:
# <ipython-input-78-e52896922c77>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   referral_ft['Age'] = (referral_ft['Notification Date'] - referral_ft['DOB'])

# %%
ft_avg_age = referral_ft['Age'].mean()

# %%
referral_gn['Age'] = (referral_gn['Notification Date'] - referral_gn['DOB'])
gn_avg_age = referral_gn['Age'].mean()
# Out:
# <ipython-input-80-638746183903>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   referral_gn['Age'] = (referral_gn['Notification Date'] - referral_gn['DOB'])

# %%
referral_md['Age'] = (referral_md['Notification Date'] - referral_md['DOB'])
referral_nw['Age'] = (referral_nw['Notification Date'] - referral_nw['DOB'])
referral_sc['Age'] = (referral_sc['Notification Date'] - referral_sc['DOB'])
referral_se['Age'] = (referral_se['Notification Date'] - referral_se['DOB'])
referral_sw['Age'] = (referral_sw['Notification Date'] - referral_sw['DOB'])
referral_uc['Age'] = (referral_uc['Notification Date'] - referral_uc['DOB'])
# Out:
# <ipython-input-81-e14d29e91f39>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   referral_md['Age'] = (referral_md['Notification Date'] - referral_md['DOB'])
# <ipython-input-81-e14d29e91f39>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   referral_nw['Age'] = (referral_nw['Notification Date'] - referral_nw['DOB'])
# <ipython-input-81-e14d29e91f39>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   referral_sc['Age'] = (referral_sc['Notification Date'] - referral_sc['DOB'])
# <ipython-input-81-e14d29e91f39>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   referral_se['Age'] = (referral_se['Notification Date'] - referral_se['DOB'])
# <ipython-input-81-e14d29e91f39>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   referral_sw['Age'] = (referral_sw['Notification Date'] - referral_sw['DOB'])
# <ipython-input-81-e14d29e91f39>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   referral_uc['Age'] = (referral_uc['Notification Date'] - referral_uc['DOB'])

# %%
md_avg_age = referral_md['Age'].mean()
nw_avg_age = referral_nw['Age'].mean()
sc_avg_age = referral_sc['Age'].mean()
se_avg_age = referral_se['Age'].mean()
sw_avg_age = referral_sw['Age'].mean()
uc_avg_age = referral_uc['Age'].mean()

# %%
print('Average age for East Tennessee:' + str(et_avg_age))
# Out:
# Average age for East Tennessee:479 days 06:28:16.665303968

# %% [markdown]
# # Are ineligibility rates higher in certain areas?

# %% [markdown]
# #### East Tennessee

# %%
et_eligibility = referral_et['Initial Eligibility'].value_counts(normalize=True).to_frame()
et_eligibility = et_eligibility.rename(columns={'Initial Eligibility': 'East Tennessee'})
et_eligibility = round(et_eligibility['East Tennessee'] * 100, 1).to_frame()

# %% [markdown]
# #### First Tennessee

# %%
ft_eligibility = referral_ft['Initial Eligibility'].value_counts(normalize=True).to_frame()
ft_eligibility = ft_eligibility.rename(columns={'Initial Eligibility': 'First Tennessee'})
ft_eligibility = round(ft_eligibility['First Tennessee'] * 100, 1).to_frame()

# %% [markdown]
# #### Greater Nashville

# %%
gn_eligibility = referral_gn['Initial Eligibility'].value_counts(normalize=True).to_frame()
gn_eligibility = gn_eligibility.rename(columns={'Initial Eligibility': 'Greater Nashville'})
gn_eligibility = round(gn_eligibility['Greater Nashville'] * 100, 1).to_frame()

# %% [markdown]
# #### Memphis Delta

# %%
md_eligibility = referral_md['Initial Eligibility'].value_counts(normalize=True).to_frame()
md_eligibility = md_eligibility.rename(columns={'Initial Eligibility': 'Memphis Delta'})
md_eligibility = round(md_eligibility['Memphis Delta'] * 100, 1).to_frame()

# %% [markdown]
# #### Northwest

# %%
nw_eligibility = referral_nw['Initial Eligibility'].value_counts(normalize=True).to_frame()
nw_eligibility = nw_eligibility.rename(columns={'Initial Eligibility': 'Northwest'})
nw_eligibility = round(nw_eligibility['Northwest'] * 100, 1).to_frame()

# %% [markdown]
# #### South Central

# %%
sc_eligibility = referral_sc['Initial Eligibility'].value_counts(normalize=True).to_frame()
sc_eligibility = sc_eligibility.rename(columns={'Initial Eligibility': 'South Central'})
sc_eligibility = round(sc_eligibility['South Central'] * 100, 1).to_frame()

# %% [markdown]
# #### Southeast

# %%
se_eligibility = referral_se['Initial Eligibility'].value_counts(normalize=True).to_frame()
se_eligibility = se_eligibility.rename(columns={'Initial Eligibility': 'Southeast'})
se_eligibility = round(se_eligibility['Southeast'] * 100, 1).to_frame()

# %% [markdown]
# #### Southwest

# %%
sw_eligibility = referral_sw['Initial Eligibility'].value_counts(normalize=True).to_frame()
sw_eligibility = sw_eligibility.rename(columns={'Initial Eligibility': 'Southwest'})
sw_eligibility = round(sw_eligibility['Southwest'] * 100, 1).to_frame()

# %% [markdown]
# #### Upper Cumberland

# %%
uc_eligibility = referral_uc['Initial Eligibility'].value_counts(normalize=True).to_frame()
uc_eligibility = uc_eligibility.rename(columns={'Initial Eligibility': 'Upper Cumberland'})
uc_eligibility = round(uc_eligibility['Upper Cumberland'] * 100, 1).to_frame()

# %%
eligibility_dfs = [et_eligibility, ft_eligibility, gn_eligibility, md_eligibility, nw_eligibility, sc_eligibility, 
                  se_eligibility, sw_eligibility, uc_eligibility]

# %%
eligibility = pd.concat(eligibility_dfs, axis = 1)
eligibility.T.sort_values(by = 'Eligible', ascending = False)
# Out:
#                    Eligible  Ineligible
# Upper Cumberland       83.8        16.2
# South Central          83.5        16.5
# First Tennessee        79.2        20.8
# Memphis Delta          77.8        22.2
# Southwest              77.6        22.4
# Greater Nashville      75.3        24.7
# Southeast              72.5        27.5
# East Tennessee         71.3        28.7
# Northwest              66.0        34.0
