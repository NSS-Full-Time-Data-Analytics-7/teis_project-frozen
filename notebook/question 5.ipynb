# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
referral_df = pd.read_excel('../data/TEIS Compiled Monthly.xlsx')

# %%
monthly_df = pd.read_excel('../data/TEIS Compiled Monthly.xlsx')

# %%
monthly_df.head(10)
# Out:
#   POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0  ET    403339 2014-08-09      Blount  Transitional   Eligibility      A
# 1  FT    404085 2013-07-31      Unicoi       At-Risk  Notification      I
# 2  FT    403623 2016-02-05    Sullivan  Transitional   Eligibility      A
# 3  FT    404157 2015-12-06    Sullivan  Transitional          IFSP      A
# 4  FT    404154 2015-04-18     Hawkins       At-Risk          IFSP      A
# 5  GN    401584 2016-03-27  Montgomery  Transitional   Eligibility      A
# 6  GN    404087 2014-10-29    Davidson   Competitive  Notification      I
# 7  GN    402274 2015-12-10  Montgomery  Transitional   Eligibility      I
# 8  MD    383596 2014-06-27      Shelby  Transitional    Evaluation      I
# 9  MD    396935 2014-12-12      Shelby  Transitional   Eligibility      A
#
#             Service Coordinator Notification/ Referral Date  \
# 0                  Kristi Borer                  2016-07-01
# ...

# %%
monthly_et = monthly_df.loc[monthly_df['POE'] == 'ET']
monthly_et

referral_df = referral_df.loc[monthly_df['POE'] == 'ET']
referral_df
monthly_et = monthly_df.loc[monthly_df['Referral Source Category'] == 'ET']
monthly_et
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Referral Source Category'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
referral_df.tail()
# Out:
#        POE  Child ID        DOB County Name    County SES  Child Phase Active  \
# 113251  UC    528759 2021-04-07      Sumner   Competitive   Evaluation      A
# 113252  UC    528534 2022-03-13      Sumner   Competitive         IFSP      A
# 113253  UC    528430 2022-01-05  Cumberland  Transitional  Eligibility      A
# 113254  UC    528253 2020-09-12      Sumner   Competitive         IFSP      A
# 113255  UC    528535 2022-02-08       Smith  Transitional   Evaluation      A
#
#        Service Coordinator Notification/ Referral Date Parent Consent Date  \
# 113251   Sherry Roberts-DS                  2022-05-16          2022-05-26
# 113252         Robyn Hogan                  2022-05-11          2022-05-23
# 113253          Lisa Davis                  2022-05-10          2022-05-18
# 113254          Taylor Lee                  2022-05-06          2022-05-11
# 113255   Sherry Roberts-DS                  2022-05-11          2022-05-27
#
# ...

# %%
pd.set_option("display.max_columns", None)

referral_df.head()
# Out:
#   POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0  ET    403339 2014-08-09      Blount  Transitional   Eligibility      A
# 1  FT    404085 2013-07-31      Unicoi       At-Risk  Notification      I
# 2  FT    403623 2016-02-05    Sullivan  Transitional   Eligibility      A
# 3  FT    404157 2015-12-06    Sullivan  Transitional          IFSP      A
# 4  FT    404154 2015-04-18     Hawkins       At-Risk          IFSP      A
#
#             Service Coordinator Notification/ Referral Date  \
# 0                  Kristi Borer                  2016-07-01
# 1  Jennifer Terranera - 45 days                  2016-07-01
# 2                   Amy Talbert                  2016-07-01
# 3                Candice Cradic                  2016-07-01
# 4                Kathy Jeffries                  2016-07-01
#
#   Parent Consent Date Referral Source Type Name Initial Eligibility  \
# 0          2016-07-01             Foster Parent            Eligible
# ...

# %%
pd.reset_option('max_columns')
monthly_df.head()
# Out:
#   POE  Child ID        DOB County Name    County SES   Child Phase Active  \
# 0  ET    403339 2014-08-09      Blount  Transitional   Eligibility      A
# 1  FT    404085 2013-07-31      Unicoi       At-Risk  Notification      I
# 2  FT    403623 2016-02-05    Sullivan  Transitional   Eligibility      A
# 3  FT    404157 2015-12-06    Sullivan  Transitional          IFSP      A
# 4  FT    404154 2015-04-18     Hawkins       At-Risk          IFSP      A
#
#             Service Coordinator Notification/ Referral Date  \
# 0                  Kristi Borer                  2016-07-01
# 1  Jennifer Terranera - 45 days                  2016-07-01
# 2                   Amy Talbert                  2016-07-01
# 3                Candice Cradic                  2016-07-01
# 4                Kathy Jeffries                  2016-07-01
#
#   Parent Consent Date  ... Service Coordinator Counter Fiscal Year.1  \
# 0          2016-07-01  ...                           1          2016
# ...

# %%
monthly_df['IFSP Count'].count()
# Out:
# 8010

# %%
print(monthly_df['POE'].max())
# Out:
# UC

# %%
monthly_df.groupby('Service Coordinator').count()
# Out:
#                       POE  Child ID   DOB  County Name  County SES  \
# Service Coordinator
# A.J. Cowan             55        55    55           55          55
# Aaron Collins         159       159   159          159         159
# Abigail Gettinger      13        13    13           13          13
# Adreean Shanklin        7         7     7            7           7
# Adrianne McPeake      108       108   108          108         108
# ...                   ...       ...   ...          ...         ...
# Virginia Thomas        36        36    36           36          36
# Wendy Burton          433       433   433          433         433
# Wendy Freeman        1866      1866  1866         1866        1866
# Yalunda Whiteside     288       288   288          288         288
# Yolanda McGee         358       358   358          358         358
#
#                      Child Phase  Active  Notification/ Referral Date  \
# Service Coordinator
# ...

# %%
referral_df.groupby(['Service Coordinator']).sum()
# Out:
#                       Child ID  Referral Count  Evaluation Count  \
# Service Coordinator
# A.J. Cowan            27400015              55              55.0
# Aaron Collins         78457170             159             159.0
# Abigail Gettinger      6636182              13              13.0
# Adreean Shanklin       2830371               7               6.0
# Adrianne McPeake      53696767             108             108.0
# ...                        ...             ...               ...
# Virginia Thomas       18593106              36              36.0
# Wendy Burton         190093014             433             275.0
# Wendy Freeman        883078307            1866             749.0
# Yalunda Whiteside    131806361             288             288.0
# Yolanda McGee        158986773             358             248.0
#
#                      Eligibility Count  IFSP Count  \
# Service Coordinator
# A.J. Cowan                        55.0        11.0
# ...

# %%
referral_df.groupby(['Referral Source Category']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [87], in <cell line: 1>()
# ----> 1 referral_df.groupby(['Referral Source Category']).count()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
# ...

# %%
referral_df.groupby(['Service Coordinator']).count()
# Out:
#                      Child ID   POE
# Service Coordinator
# A.J. Cowan                 55    55
# Aaron Collins             159   159
# Abigail Gettinger          13    13
# Adreean Shanklin            7     7
# Adrianne McPeake          108   108
# ...                       ...   ...
# Virginia Thomas            36    36
# Wendy Burton              433   433
# Wendy Freeman            1866  1866
# Yalunda Whiteside         288   288
# Yolanda McGee             358   358
#
# [419 rows x 2 columns]

# %%
referral_df = referral_df[['Service Coordinator', 'Child ID','POE']]
referral_df
# Out:
#                  Service Coordinator  Child ID POE
# 0                       Kristi Borer    403339  ET
# 1       Jennifer Terranera - 45 days    404085  FT
# 2                        Amy Talbert    403623  FT
# 3                     Candice Cradic    404157  FT
# 4                     Kathy Jeffries    404154  FT
# ...                              ...       ...  ..
# 113251             Sherry Roberts-DS    528759  UC
# 113252                   Robyn Hogan    528534  UC
# 113253                    Lisa Davis    528430  UC
# 113254                    Taylor Lee    528253  UC
# 113255             Sherry Roberts-DS    528535  UC
#
# [113256 rows x 3 columns]

# %%
monthly_df = monthly_df[['Service Coordinator', 'Child ID','POE']]
monthly_df
# Out:
#                  Service Coordinator  Child ID POE
# 0                       Kristi Borer    403339  ET
# 1       Jennifer Terranera - 45 days    404085  FT
# 2                        Amy Talbert    403623  FT
# 3                     Candice Cradic    404157  FT
# 4                     Kathy Jeffries    404154  FT
# ...                              ...       ...  ..
# 113251             Sherry Roberts-DS    528759  UC
# 113252                   Robyn Hogan    528534  UC
# 113253                    Lisa Davis    528430  UC
# 113254                    Taylor Lee    528253  UC
# 113255             Sherry Roberts-DS    528535  UC
#
# [113256 rows x 3 columns]

# %%
monthly_df.(['Referral Source Category']).counts()
# Out:
#   Input In [85]
#     monthly_df.(['Referral Source Category']).counts()
#                ^
# SyntaxError: invalid syntax

# %%
referral_df.groupby(['Referral Source Category']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [86], in <cell line: 1>()
# ----> 1 referral_df.groupby(['Referral Source Category']).count()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
# ...
